# %% [markdown]
# # breast cancer Regression
#
# breast cancer 데이터셋을 이용해 연속형 값을 예측하는 회귀 문제를 수행하였다.
# X는 입력 특성으로, y는 예측할 수치 데이터로 사용하였다.
#
# - 이번 유방암 회귀 테스트의 평균제곱오차(MSE)는 약 43063.60으로 측정되었다. 회귀 문제는 예측값과 실제값의 차이를 제곱하여 평가하므로, 값의 크기가 비교적 크게 나타날 수 있다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

from tensorflow.keras import layers, models

# %%
path = '/Users/ganghyejun/Desktop/100_College/2-1/인공지능개론/AICLASS_2-1/task/src/data/breast_cancer.csv'
df = pd.read_csv(path)

# %%
y = df['worst area']
X = df.drop(['worst area', 'label'], axis=1)

# 1. X를 numpy로 변환 + 스케일링
scaler = StandardScaler()
X = scaler.fit_transform(X)

# 2. train/test 분리
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0
)

# 3. 딥러닝 회귀 모델
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

model.compile(
    optimizer='adam',
    loss='mse',
    metrics=['mse']
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/ganghyejun/Desktop/100_College/2-1/인공지능개론/AICLASS_2-1/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 1024673.2500 - mse: 1024673.2500 - val_loss: 1476678.3750 - val_mse: 1476678.3750
# Epoch 2/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1018239.7500 - mse: 1018239.7500 - val_loss: 1465063.8750 - val_mse: 1465063.8750
# Epoch 3/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1006013.1250 - mse: 1006013.1250 - val_loss: 1441661.1250 - val_mse: 1441661.1250
# Epoch 4/50
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 982736.3750 - mse: 982736.3750 - val_loss: 1398300.6250 - val_mse: 1398300.6250
# Epoch 5/50
# ...

# %%
# 4. 예측 및 평가
y_pred = model.predict(X_test)

print(mean_squared_error(y_test, y_pred))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 43063.59507119403
