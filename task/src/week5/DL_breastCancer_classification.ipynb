# %% [markdown]
# # Breast Cancer Classification
#
# breast cancer 데이터셋을 이용해 종양의 클래스를 분류하는 딥러닝 분류 문제를 수행하였다.
# 입력 데이터와 정답 데이터를 나눈 뒤, y를 원-핫 인코딩하여 딥러닝 모델을 학습시켰다.
# 이번 실험에서 정확도는 약 0.97로 높게 측정되었으며, confusion matrix를 통해 대부분의 샘플이 정확히 분류되고 일부만 오분류되었음을 확인하였다.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras import layers, models

# %%
path = '/Users/ganghyejun/Desktop/100_College/2-1/인공지능개론/AICLASS_2-1/task/src/data/breast_cancer.csv'
df = pd.read_csv(path)
df = pd.read_csv(path, index_col=0)

# %%
y = df['label']
X = df.drop('label', axis=1)

# 1. X를 numpy로 변환 + 스케일링
scaler = StandardScaler()
X = scaler.fit_transform(X)

# 2. train/test 분리
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=0
)

# 3. y를 원-핫 인코딩
classes = sorted(y.unique())
y_train = pd.get_dummies(y_train).reindex(columns=classes, fill_value=0).values
y_test = pd.get_dummies(y_test).reindex(columns=classes, fill_value=0).values

# 4. 딥러닝 분류 모델
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),
    layers.Dense(32, activation='relu'),
    layers.Dense(y_train.shape[1], activation='softmax')
])

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=50,
    batch_size=16,
    verbose=1
)
# Out:
# Epoch 1/50
# /Users/ganghyejun/Desktop/100_College/2-1/인공지능개론/AICLASS_2-1/.venv/lib/python3.12/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7824 - loss: 0.5055 - val_accuracy: 0.9651 - val_loss: 0.2409
# Epoch 2/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9206 - loss: 0.2318 - val_accuracy: 1.0000 - val_loss: 0.1323
# Epoch 3/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9588 - loss: 0.1510 - val_accuracy: 1.0000 - val_loss: 0.0903
# Epoch 4/50
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.1116 - val_accuracy: 1.0000 - val_loss: 0.0703
# Epoch 5/50
# ...

# %%
# 5. 예측 및 평가
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test, axis=1)
y_pred_class = np.argmax(y_pred, axis=1)

print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        53
#            1       0.98      0.97      0.97        90
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.96      0.96       143
# weighted avg       0.97      0.97      0.97       143
#
# [[51  2]
#  [ 3 87]]
